# %% [markdown]
# # 1 Introducción

# %% [markdown]
# **Documentación de transformers:**
# * **Get started:** $\;$ TL02
# * **Clases base:** $\;$ TL03
# * **Inferencia:**
#     * **API Pipeline:**  $\;$ TL03
#     * **LLMs:** $\;$ TL06
#     * **Chat with models:** $\;$ TL07
# * **Entrenamiento:**
#     * **API Trainer:** $\;$ TL08

# %% [markdown]
# **Otras librerías y recursos:**
# * [**pytorch**](https://pytorch.org) $\;$ TL01
# * [**datasets:**](https://huggingface.co/docs/datasets/index) $\;$ TL04
# * [**evaluate:**](https://huggingface.co/docs/evaluate/index) $\;$ TL04
# * Benchmarking: $\;$ TL06
# * [**accelerate:**](https://huggingface.co/docs/accelerate/index#accelerate) $\;$ TL08
# * [**PEFT:**](https://huggingface.co/docs/peft) $\;$ TL09
# * [**lighteval:**](https://huggingface.co/docs/lighteval) $\;$ secciones siguientes

# %% [markdown]
# **Objetivo:** $\;$ introducir lighteval

# %% [markdown]
# <p style="page-break-after:always;"></p>
