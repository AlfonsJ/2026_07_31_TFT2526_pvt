# %%
from vllm import LLM, SamplingParams
# Out:
# INFO 11-18 12:45:04 [__init__.py:216] Automatically detected platform cuda.

# %%
prompts = [
    "Hello, my name is",
    "The president of the United States is",
    "The capital of France is",
    "The future of AI is",
]
sampling_params = SamplingParams(temperature=0.8, top_p=0.95)

# %%
def main():
    # Create an LLM.
    llm = LLM(model="facebook/opt-125m")
    # Generate texts from the prompts.
    # The output is a list of RequestOutput objects
    # that contain the prompt, generated text, and other information.
    outputs = llm.generate(prompts, sampling_params)
    # Print the outputs.
    print("\nGenerated Outputs:\n" + "-" * 60)
    for output in outputs:
        prompt = output.prompt
        generated_text = output.outputs[0].text
        print(f"Prompt:    {prompt!r}")
        print(f"Output:    {generated_text!r}")
        print("-" * 60)

# %%
if __name__ == "__main__":
    main()
# Out:
# INFO 11-18 12:45:04 [utils.py:328] non-default args: {'disable_log_stats': True, 'model': 'facebook/opt-125m'}
# INFO 11-18 12:45:08 [__init__.py:742] Resolved architecture: OPTForCausalLM
# `torch_dtype` is deprecated! Use `dtype` instead!
# INFO 11-18 12:45:08 [__init__.py:1815] Using max model len 2048
# INFO 11-18 12:45:08 [scheduler.py:222] Chunked prefill is enabled with max_num_batched_tokens=8192.
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:09 [core.py:654] Waiting for init message from front-end.
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:09 [core.py:76] Initializing a V1 LLM engine (v0.10.2) with config: model='facebook/opt-125m', speculative_config=None, tokenizer='facebook/opt-125m', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=2048, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=facebook/opt-125m, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2","vllm.mamba_mixer","vllm.short_conv","vllm.linear_attention","vllm.plamo2_mamba_mixer","vllm.gdn_attention"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":1,"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"pass_config":{},"max_capture_size":512,"local_cache_dir":null}
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:10 [parallel_state.py:1165] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# (EngineCore_DP0 pid=264766) WARNING 11-18 12:45:10 [topk_topp_sampler.py:69] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:10 [gpu_model_runner.py:2338] Starting to load model facebook/opt-125m...
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:10 [gpu_model_runner.py:2370] Loading model from scratch...
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:10 [cuda.py:362] Using Flash Attention backend on V1 engine.
# [W1118 12:45:10.209869233 ProcessGroupNCCL.cpp:981] Warning: TORCH_NCCL_AVOID_RECORD_STREAMS is the default now, this environment variable is thus deprecated. (function operator())
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:11 [weight_utils.py:348] Using model weights format ['*.safetensors', '*.bin', '*.pt']
# Loading pt checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:11 [default_loader.py:268] Loading weights took 0.10 seconds
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:11 [gpu_model_runner.py:2392] Model loading took 0.2389 GiB and 0.733477 seconds
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:12 [backends.py:539] Using cache directory: /home/ajuan/.cache/vllm/torch_compile_cache/d38601f6d6/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:12 [backends.py:550] Dynamo bytecode transform time: 0.65 s
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:12 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 0.144 s
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:12 [monitor.py:34] torch.compile takes 0.65 s in total
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:13 [gpu_worker.py:298] Available KV cache memory: 20.44 GiB
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:13 [kv_cache_utils.py:864] GPU KV cache size: 595,376 tokens
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:13 [kv_cache_utils.py:868] Maximum concurrency for 2,048 tokens per request: 290.71x
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 67/67 [00:00<00:00, 199.75it/s]
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:14 [gpu_model_runner.py:3118] Graph capturing finished in 1 secs, took 0.21 GiB
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:14 [gpu_worker.py:391] Free memory on device (22.98/23.53 GiB) on startup. Desired GPU memory utilization is (0.9, 21.17 GiB). Actual usage is 0.24 GiB for weight, 0.48 GiB for peak activation, 0.02 GiB for non-torch memory, and 0.21 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=21566337843` to fit into requested memory, or `--kv-cache-memory=23509434368` to fully utilize gpu memory. Current kv cache memory in use is 21948019507 bytes.
# (EngineCore_DP0 pid=264766) INFO 11-18 12:45:14 [core.py:218] init engine (profile, create kv cache, warmup model) took 2.38 seconds
# INFO 11-18 12:45:14 [llm.py:295] Supported_tasks: ['generate']
# INFO 11-18 12:45:14 [__init__.py:36] No IOProcessor plugins requested by the model
# Adding requests:   0%|          | 0/4 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/4 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Generated Outputs:
# ------------------------------------------------------------
# Prompt:    'Hello, my name is'
# Output:    ' Joel, my dad is my friend and we are in a relationship. I am'
# ------------------------------------------------------------
# Prompt:    'The president of the United States is'
# Output:    ' reportedly being investigated by the FBI over the allegations that he broke campaign finance laws in'
# ------------------------------------------------------------
# Prompt:    'The capital of France is'
# Output:    ' all set to open a new gateway to the most notorious terror camps in Europe,'
# ------------------------------------------------------------
# Prompt:    'The future of AI is'
# Output:    ' in their hands. We cannot prevent the future.\n\nFor more than a'
# ------------------------------------------------------------
