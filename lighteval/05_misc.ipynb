# %% [markdown]
# [**OpenEvals:**](https://huggingface.co/OpenEvals) $\;$ equipo HF sobre Evaluación; desarrolla y mantiene:
# * [**lighteval:**](https://github.com/huggingface/lighteval) $\;$ librería de evaluación de LLMs
# * [**evaluation guidebook:**](https://github.com/huggingface/evaluation-guidebook) $\;$ guía de referencia para evaluación de LLMs
# * [**leaderboards on the hub:**](https://huggingface.co/blog?tag=leaderboard) $\;$ clasificaciones en abierto
